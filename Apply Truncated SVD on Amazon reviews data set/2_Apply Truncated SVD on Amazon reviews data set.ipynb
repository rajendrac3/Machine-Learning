# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")


import sqlite3
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer

import re
# Tutorial about Python regular expressions: https://pymotw.com/2/re/
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle

from tqdm import tqdm
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-229-6db90e9297aa> in <module>()
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#
# ImportError: No module named 'google.colab'

# %%
#connecting to sqlite db
# con = sqlite3.connect('/content/gdrive/My Drive/Colab Notebooks/Assignment 4/database.sqlite')
con = sqlite3.connect('database.sqlite')
                      
# filtering only positive and negative reviews i.e. 
# not taking into consideration those reviews with Score=3
# SELECT * FROM Reviews WHERE Score != 3 LIMIT 500000, will give top 500000 data points
# you can change the number to any other number based on your computing power

# filtered_data = pd.read_sql_query(""" SELECT * FROM Reviews WHERE Score != 3 LIMIT 500000""", con) 
# for tsne assignment you can take 5k data points

filtered_data = pd.read_sql_query(""" SELECT * FROM Reviews WHERE Score != 3""", con) 

# Give reviews with Score>3 a positive rating(1), and reviews with a score<3 a negative rating(0).
def partition(x):
    if x < 3:
        return 0
    return 1

#changing reviews with score less than 3 to be positive and vice-versa
actualScore = filtered_data['Score']
positiveNegative = actualScore.map(partition) 
filtered_data['Score'] = positiveNegative
print("Number of data points in our data", filtered_data.shape)
filtered_data.head(3)
# Out:
# Number of data points in our data (525814, 10)
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      1  1303862400
# 1                     0                       0      0  1346976000
# 2                     1                       1      1  1219017600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...

# %%
display = pd.read_sql_query("""
SELECT UserId, ProductId, ProfileName, Time, Score, Text, COUNT(*)
FROM Reviews
GROUP BY UserId
HAVING COUNT(*)>1
""", con)

# %%
print(display.shape)
display.head()
# Out:
# (80668, 7)
#                UserId   ProductId             ProfileName        Time  Score  \
# 0  #oc-R115TNMSPFT9I7  B007Y59HVM                 Breyton  1331510400      2
# 1  #oc-R11D9D7SHXIJB9  B005HG9ET0  Louis E. Emory "hoppy"  1342396800      5
# 2  #oc-R11DNU2NBKQ23Z  B007Y59HVM        Kim Cieszykowski  1348531200      1
# 3  #oc-R11O5J5ZVQE25C  B005HG9ET0           Penguin Chick  1346889600      5
# 4  #oc-R12KPBODL2B5ZD  B007OSBE1U   Christopher P. Presta  1348617600      1
#
#                                                 Text  COUNT(*)
# 0  Overall its just OK when considering the price...         2
# 1  My wife has recurring extreme muscle spasms, u...         3
# 2  This coffee is horrible and unfortunately not ...         2
# 3  This will be the bottle that you grab from the...         3
# 4  I didnt like this coffee. Instead of telling y...         2

# %%
# Removing duplicate reviews
final=filtered_data.drop_duplicates(subset={"UserId","ProfileName","Time","Text"}, keep='first', inplace=False)
print(final.shape)
# Out:
# (364173, 10)

# %%
(final['Id'].size*1.0)/(filtered_data['Id'].size*1.0)*100
# Out:
# 69.25890143662969

# %%
final=final[final.HelpfulnessNumerator<=final.HelpfulnessDenominator]

# %%
#Before starting the next phase of preprocessing lets see the number of entries left
print(final.shape)

#How many positive and negative reviews are present in our dataset?
final['Score'].value_counts()
# Out:
# (364171, 10)
# 1    307061
# 0     57110
# Name: Score, dtype: int64

# %%
final["cleanReview"] = final["Summary"].map(str) + ". " + final["Text"]

# %%
final['cleanReview'].head()
# Out:
# 0    Good Quality Dog Food. I have bought several o...
# 1    Not as Advertised. Product arrived labeled as ...
# 2    "Delight" says it all. This is a confection th...
# 3    Cough Medicine. If you are looking for the sec...
# 4    Great taffy. Great taffy at a great price.  Th...
# Name: cleanReview, dtype: object

# %%
final['lengthOfReview'] = final['cleanReview'].str.split().str.len()
final['lengthOfReview'].head()
# Out:
# 0    52
# 1    34
# 2    98
# 3    43
# 4    29
# Name: lengthOfReview, dtype: int64

# %%
#remove urls from text python
from tqdm import tqdm
lst = []
removed_urls_list = []
for text in tqdm(final['cleanReview']):
  removed_urls_text = re.sub(r"http\S+", "", text)
  lst.append(removed_urls_text)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 364171/364171 [00:01<00:00, 348689.13it/s]

# %%
#remove urls from text python
removed_urls_list = []
for text in tqdm(lst):
  removed_urls_text = re.sub(r"http\S+", "", text)
  removed_urls_list.append(removed_urls_text)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 364171/364171 [00:00<00:00, 545983.46it/s]

# %%
from bs4 import BeautifulSoup
text_lst = []
for text in tqdm(removed_urls_list):
  soup = BeautifulSoup(text, 'lxml')
  text = soup.get_text()
  text_lst.append(text)
# print(text)
# print("="*50)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 364171/364171 [02:07<00:00, 2863.46it/s]

# %%
print(len(final['cleanReview']))
# Out:
# 364171

# %%
# https://stackoverflow.com/a/47091490/4084039
import re

def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %%
decat_lst = []
for decat_text in tqdm(text_lst):
  text = decontracted(decat_text)
  decat_lst.append(text)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 364171/364171 [00:05<00:00, 67496.57it/s]

# %%
strip_list = []
for to_strip in tqdm(decat_lst):
  text = re.sub("\S*\d\S*", "", to_strip).strip()
  strip_list.append(text)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 364171/364171 [00:19<00:00, 18494.66it/s]

# %%
spatial_list = []
for to_spatial in tqdm(strip_list):
  text = re.sub('[^A-Za-z0-9]+', ' ', to_spatial)
  spatial_list.append(text)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 364171/364171 [00:09<00:00, 36464.50it/s]

# %%
stopwords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"])

# %%
# Combining all the above stundents 
preprocessed_reviews = []
# tqdm is for printing the status bar
for sentance in tqdm(spatial_list):
    sentance = re.sub(r"http\S+", "", sentance)
    sentance = BeautifulSoup(sentance, 'lxml').get_text()
    sentance = decontracted(sentance)
    sentance = re.sub("\S*\d\S*", "", sentance).strip()
    sentance = re.sub('[^A-Za-z]+', ' ', sentance)
    # https://gist.github.com/sebleier/554280
    sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopwords)
    preprocessed_reviews.append(sentance.strip())
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 364171/364171 [02:01<00:00, 2999.66it/s]

# %%
print(len(preprocessed_reviews))
preprocessed_reviews[-1]
# Out:
# 364171
# 'great honey satisfied product advertised use cereal raw vinegar general sweetner'

# %%
final['cleanReview'] = preprocessed_reviews

# %%
print(len(final))
final.tail(5)
# Out:
# 364171
#             Id   ProductId          UserId              ProfileName  \
# 525809  568450  B001EO7N10  A28KG5XORO54AY         Lettie D. Carter
# 525810  568451  B003S1WTCU  A3I8AFVPEE8KI5                R. Sawyer
# 525811  568452  B004I613EE  A121AA1GQV751Z            pksd "pk_007"
# 525812  568453  B004I613EE   A3IBEVCTXKNOH  Kathy A. Welch "katwel"
# 525813  568454  B001LR2CU2  A3LGQPJCZVL9UC                 srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 525809                     0                       0      1  1299628800
# 525810                     0                       0      0  1331251200
# 525811                     2                       2      1  1329782400
# 525812                     1                       1      1  1331596800
# 525813                     0                       0      1  1338422400
#
#                                    Summary  \
# 525809                 Will not do without
# 525810                        disappointed
# 525811            Perfect for our maltipoo
# 525812  Favorite Training and reward treat
# 525813                         Great Honey
#
#                                                      Text  \
# 525809  Great for sesame chicken..this is a good if no...
# 525810  I'm disappointed with the flavor. The chocolat...
# 525811  These stars are small, so you can give 10-15 o...
# 525812  These are the BEST treats for training and rew...
# 525813  I am very satisfied ,product is as advertised,...
#
#                                               cleanReview  lengthOfReview
# 525809  not without great sesame chicken good not bett...              15
# 525810  disappointed disappointed flavor chocolate not...              24
# 525811  perfect maltipoo stars small give one training...              40
# 525812  favorite training reward treat best treats tra...              22
# 525813  great honey satisfied product advertised use c...              11

# %%
final['cleanReview'][0]
# Out:
# 'good quality dog food bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better'

# %%
final['lengthOfReview'][0]
# Out:
# 27

# %%
dir_path = os.getcwd()
# conn = sqlite3.connect(os.path.join(dir_path, '/content/gdrive/My Drive/Colab Notebooks/Assignment 4/final.sqlite'))
conn = sqlite3.connect(os.path.join(dir_path, 'final.sqlite'))
# final.to_sql('Reviews', conn, if_exists='replace', index=False)

# %%
review_3 = pd.read_sql_query(""" SELECT count(*) FROM Reviews""", conn)
print(review_3)
# Out:
#    count(*)
# 0    364171

# %%
filtered_data = pd.read_sql_query(""" SELECT * FROM Reviews""", conn)

# %%
filtered_data.shape
# Out:
# (364171, 13)

# %%
filtered_data["Time"] = pd.to_datetime(filtered_data["Time"], unit = "s")
filtered_data = filtered_data.sort_values(by = "Time")

# %%
filtered_data.head(5)
# Out:
#             Id   ProductId          UserId               ProfileName  \
# 117924  150524  0006641040   ACITT7DI6IDDL           shari zychinski
# 117901  150501  0006641040   AJ46FKXOVC7NR        Nicholas A Mesiano
# 298792  451856  B00004CXX9   AIUWLEQ1ADEG5          Elizabeth Medina
# 169281  230285  B00004RYGX  A344SMIA5JECGM           Vincent P. Ross
# 298791  451855  B00004CXX9   AJH6LUC1UT1ON  The Phantom of the Opera
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score       Time  \
# 117924                     0                       0      1 1999-10-08
# 117901                     2                       2      1 1999-10-25
# 298792                     0                       0      1 1999-12-02
# 169281                     1                       2      1 1999-12-06
# 298791                     0                       0      1 2000-01-03
#
#                                                   Summary  \
# 117924                          EVERY book is educational
# 117901  This whole series is great way to spend time w...
# 298792                               Entertainingl Funny!
# 169281                            A modern day fairy tale
# 298791                                         FANTASTIC!
#
#                                                      Text  \
# 117924  this witty little book makes my son laugh at l...
# 117901  I can remember seeing the show when it aired o...
# 298792  Beetlejuice is a well written movie ..... ever...
# 169281  A twist of rumplestiskin captured on film, sta...
# 298791  Beetlejuice is an excellent and funny movie. K...
#
#                                               cleanReview  lengthOfReview  \
# 117924  EVERY book is educational. this witty little b...              78
# 117901  This whole series is great way to spend time w...              90
# 298792  Entertainingl Funny!. Beetlejuice is a well wr...              31
# 169281  A modern day fairy tale. A twist of rumplestis...              41
# 298791  FANTASTIC!. Beetlejuice is an excellent and fu...              44
#
#                                         Preprocessed_text
# 117924  witty little book makes son laugh loud recite ...
# 117901  remember seeing show aired television years ag...
# 298792  beetlejuice well written movie everything exce...
# 169281  twist rumplestiskin captured film starring mic...
# 298791  beetlejuice excellent funny movie keaton hilar...

# %%
print(len(filtered_data))
filtered_data.info()
filtered_data = filtered_data.head(100000)
print(len(filtered_data))
# Out:
# 364171
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364171 entries, 117924 to 107253
# Data columns (total 13 columns):
# Id                        364171 non-null int64
# ProductId                 364171 non-null object
# UserId                    364171 non-null object
# ProfileName               364171 non-null object
# HelpfulnessNumerator      364171 non-null int64
# HelpfulnessDenominator    364171 non-null int64
# Score                     364171 non-null int64
# Time                      364171 non-null datetime64[ns]
# Summary                   364171 non-null object
# Text                      364171 non-null object
# cleanReview               364171 non-null object
# lengthOfReview            364171 non-null int64
# Preprocessed_text         364171 non-null object
# dtypes: datetime64[ns](1), int64(5), object(7)
# memory usage: 38.9+ MB
# 100000

# %%
filtered_data['Score'].value_counts()
# Out:
# 1    87729
# 0    12271
# Name: Score, dtype: int64

# %%
X = filtered_data["cleanReview"]
print(print("shape of X:", X.head(5)))
y = filtered_data["Score"]
print("shape of y:", y.head(5))
X_len = filtered_data['lengthOfReview']
# Out:
# shape of X: 117924    EVERY book is educational. this witty little b...
# 117901    This whole series is great way to spend time w...
# 298792    Entertainingl Funny!. Beetlejuice is a well wr...
# 169281    A modern day fairy tale. A twist of rumplestis...
# 298791    FANTASTIC!. Beetlejuice is an excellent and fu...
# Name: cleanReview, dtype: object
# None
# shape of y: 117924    1
# 117901    1
# 298792    1
# 169281    1
# 298791    1
# Name: Score, dtype: int64

# %%
len(filtered_data['lengthOfReview'])
# Out:
# 100000

# %%
X_train = X[0:100000]
Y_train = y[0:100000]

# %%
print(len(X_train))
print(len(Y_train))
# Out:
# 100000
# 100000

# %%
print(X_train.shape)
print(X_train.shape)
# Out:
# (100000,)
# (100000,)

# %% [markdown]
# ###

# %% [markdown]
# # Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer 

count_vect = CountVectorizer()
X_train_vect = count_vect.fit_transform(X_train)
X_test_vect = count_vect.transform(X_test)
X_val_vect = count_vect.transform(X_val)
feature_names = count_vect.get_feature_names()
# BoW_dict = {'X_train_vect':X_train_vect, 'X_test_vect': X_test_vect, 'X_val_vect': X_val_vect}
print(X_train_vect.shape)
# print(feature_names)
# Out:
# (60000, 48270)

# %%
X_train_vect.shape
# Out:
# (60000, 48270)

# %%
len(filtered_data['lengthOfReview'])
# Out:
# 100000

# %%
from scipy.sparse import hstack
# len_review = final['lengthOfReview'].to_sparse()
concat_data = hstack((X_train_vect,np.array(filtered_data['lengthOfReview'][0:60000])[:,None]))
concat_data_val = hstack((X_val_vect,np.array(filtered_data['lengthOfReview'][60000:80000])[:,None]))
concat_data_test = hstack((X_test_vect,np.array(filtered_data['lengthOfReview'][80000:100000])[:,None]))

# %%
print(concat_data.shape)
print(concat_data_val.shape)
print(concat_data_test.shape)
# Out:
# (60000, 47536)
# (20000, 47536)
# (20000, 47536)

# %%
print(len(feature_names))
# Out:
# 47535

# %%
BoW_dict = {'X_train_vect':concat_data, 'X_test_vect': concat_data_test, 'X_val_vect': concat_data_val}
print(BoW_dict['X_train_vect'].shape)
# Out:
# (60000, 47536)

# %%
import pickle
with open('BoW.pkl', 'wb') as handle:
    pickle.dump(BoW_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## TF-IDF

# %%
tf_idf_vect = TfidfVectorizer(min_df=10)
train_tf_idf = tf_idf_vect.fit_transform(X_train)

print("the shape of out text TFIDF vectorizer ",train_tf_idf.get_shape())
print("the type of count vectorizer ",type(train_tf_idf))
print("the number of unique words including both unigrams and bigrams ", train_tf_idf.get_shape()[1])
# Out:
# the shape of out text TFIDF vectorizer  (100000, 13374)
# the type of count vectorizer  <class 'scipy.sparse.csr.csr_matrix'>
# the number of unique words including both unigrams and bigrams  13374

# %%
tf_idf_dict = {'train_tf_idf': train_tf_idf}

# %%
import pickle
with open('tf_idf.pkl', 'wb') as handle:
    pickle.dump(tf_idf_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## TruncatedSVD on tfidf

# %%
import pickle
# with open(r"/content/gdrive/My Drive/Colab Notebooks/Assignment 4/tf_idf.pkl", "rb") as input_file:
with open(r"tf_idf.pkl", "rb") as input_file:
    tfidf_dict = pickle.load(input_file)

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD()
svd.fit(tfidf_dict['train_tf_idf'])
# Out:
# TruncatedSVD(algorithm='randomized', n_components=2, n_iter=5,
#        random_state=None, tol=0.0)

# %%
y = dict(zip(tf_idf_vect.get_feature_names(), tf_idf_vect.idf_))

# %%
from collections import OrderedDict
from operator import itemgetter

sorted_dict = OrderedDict(sorted(y.items(), key = itemgetter(1), reverse=True))

# %%
top_features = list(sorted_dict)[:2000]

# %%
print(len(top_features))
top_features[0]
# Out:
# 2000
# 'enlightening'

# %%
top_features
# Out:
# ['enlightening',
#  'gnc',
#  'bays',
#  'survives',
#  '320',
#  'singapore',
#  'inaccurate',
#  'courses',
#  'baggy',
#  'yucca',
#  'yelling',
#  'gingersnaps',
#  'steroids',
#  'meatball',
#  'carrs',
#  'curled',
#  'conspiracy',
#  'yankee',
#  'hippie',
#  'parthenon',
#  'crime',
#  'swings',
#  'putrid',
#  'kukicha',
#  'stuffy',
#  'grazing',
#  'checkup',
#  'cheeper',
#  'meter',
#  'doggone',
#  'primo',
#  'testament',
#  'chiropractor',
#  'skyline',
#  'pluses',
#  'lighten',
#  'grrrreat',
#  'tampered',
#  'mtn',
#  'rubbish',
#  'arnold',
#  'ethically',
#  'cruel',
#  'collapse',
#  'actor',
#  '1987',
#  'turtles',
#  'shooting',
#  'advent',
#  'seperately',
#  'kirsch',
#  'usualy',
#  'gourment',
#  'farmhouse',
#  'scarlet',
#  'loser',
#  'deb',
#  'unto',
#  'macho',
#  'wishlist',
#  'accepts',
#  'senna',
#  'sparked',
#  'achievement',
#  'bison',
#  'athletic',
#  'africans',
#  'folds',
#  'super5mix',
#  'chaser',
#  'tahitian',
#  'acetate',
#  'wrappings',
#  'bisto',
#  'dinty',
#  'smother',
#  'mmmmmmmmmm',
#  'harsher',
#  'tso',
#  'keenwa',
#  'breeders',
#  'clark',
#  'injured',
#  'corp',
#  'pointless',
#  'expanding',
#  'reshipped',
#  'cytosport',
#  'downtown',
#  'engage',
#  'maraschino',
#  'doxie',
#  'hampshire',
#  'tenth',
#  'stare',
#  'zhejiang',
#  'rendering',
#  'julie',
#  'attracting',
#  'install',
#  'presses',
#  'xylosweet',
#  'offended',
#  'offending',
#  'sliding',
#  'atrocious',
#  'glutten',
#  'wholegrain',
#  'russells',
#  'oxidents',
#  'burping',
#  'egcg',
#  'invested',
#  'enthused',
#  'shorten',
#  'scotsman',
#  'succeed',
#  'petal',
#  'possessed',
#  'caking',
#  'ti',
#  'civilized',
#  'overdue',
#  'sibling',
#  'dallmayr',
#  'brooks',
#  'secretion',
#  'occassional',
#  '25mg',
#  'punjab',
#  'incase',
#  'alarmed',
#  'brim',
#  'enterprise',
#  'blenders',
#  'shaving',
#  'presumed',
#  'clicker',
#  'agenda',
#  'sieve',
#  'subs',
#  'richards',
#  'feasible',
#  'bm',
#  'sympathy',
#  '11oz',
#  'nuisance',
#  'envirokids',
#  'companys',
#  'porterhouse',
#  'investigated',
#  'willow',
#  'chakra',
#  'gorge',
#  'medaglia',
#  'hosting',
#  'southeastern',
#  'photograph',
#  'consumes',
#  'snacked',
#  'lactaid',
#  'hitch',
#  'glazes',
#  'mic',
#  'awaken',
#  'trustworthy',
#  'wildflower',
#  'nando',
#  'salada',
#  'recived',
#  'addressing',
#  'shark',
#  'tis',
#  'nibbled',
#  'occassions',
#  'atom',
#  'horizons',
#  'mfg',
#  'poker',
#  'chopper',
#  'dietetic',
#  'highlander',
#  'cindy',
#  'faq',
#  'pissed',
#  'polluted',
#  'decisions',
#  'renewal',
#  'whoppers',
#  'jellybeans',
#  'incl',
#  'dispensed',
#  'tai',
#  'contender',
#  'classmates',
#  'ludicrous',
#  'cherished',
#  'refridgerate',
#  'mgs',
#  'contribution',
#  'squeaker',
#  'coatings',
#  'centered',
#  'wilted',
#  'groggy',
#  'des',
#  'cole',
#  'entertains',
#  'drake',
#  'varietal',
#  'decreasing',
#  'worrisome',
#  '31g',
#  'aquarium',
#  'elmo',
#  'preface',
#  'winn',
#  'kombu',
#  'delicacies',
#  'houseplants',
#  'gene',
#  'ds',
#  'tamper',
#  'scientifically',
#  'vitaspelt',
#  'dribble',
#  'healther',
#  'yummies',
#  'boredom',
#  'eskimo',
#  'chive',
#  'vernor',
#  'roles',
#  'attachment',
#  'deliberately',
#  'humanity',
#  'fowler',
#  'goof',
#  'junior',
#  'symphony',
#  'slaw',
#  'vigor',
#  'basketball',
#  'shout',
#  'blaming',
#  'gelato',
#  'slimming',
#  'loafs',
#  'koala',
#  'transformation',
#  '3yr',
#  'resent',
#  'virtuous',
#  'rubbermaid',
#  'americanized',
#  'sulphur',
#  'northwestern',
#  'traveler',
#  'definitive',
#  'fearful',
#  'parsely',
#  'sender',
#  'ketchups',
#  'finn',
#  'seeded',
#  'cooke',
#  'chilean',
#  'pier',
#  'gnawed',
#  'indulged',
#  'reactive',
#  'emailing',
#  'strenuous',
#  'zensoy',
#  'ewww',
#  'glitter',
#  'ummmm',
#  'muscular',
#  'pleasingly',
#  'pruned',
#  'glutton',
#  'sunridge',
#  'magazines',
#  'impatient',
#  'smokies',
#  'monitored',
#  'goofy',
#  'lycopene',
#  'sayings',
#  'colby',
#  'bernard',
#  'cobblers',
#  'brocolli',
#  'cheeky',
#  'antidote',
#  'treadmill',
#  'rediscovered',
#  'stares',
#  'narrowed',
#  'thinkthin',
#  'sheepdog',
#  'pomegranates',
#  'housing',
#  'honored',
#  'attacked',
#  'funniest',
#  'hind',
#  'spins',
#  'performing',
#  'immense',
#  'proclaimed',
#  'finals',
#  'tamped',
#  'plot',
#  'thickly',
#  'stabilized',
#  'salem',
#  'hollandaise',
#  'snip',
#  'leeks',
#  'bp',
#  'condo',
#  'yip',
#  'examination',
#  'kernal',
#  'carber',
#  'peaks',
#  'editor',
#  'thereof',
#  'imparted',
#  'drowning',
#  'prominently',
#  'pony',
#  'ringing',
#  'wifes',
#  'huckleberries',
#  'dragonwell',
#  'germs',
#  'rehab',
#  'realizes',
#  'duke',
#  'statements',
#  'indispensible',
#  'ff',
#  'yummmmmy',
#  'unbalanced',
#  'salivate',
#  'projected',
#  'cooperative',
#  'knot',
#  'brilliantly',
#  'coincidentally',
#  'solidified',
#  'citizens',
#  'antique',
#  'socal',
#  'moods',
#  'scorched',
#  'fools',
#  'preventative',
#  'verde',
#  'ly',
#  'nissin',
#  'plantations',
#  'commendable',
#  'sr',
#  'subcribe',
#  'nozzle',
#  'sprung',
#  'retails',
#  'numbing',
#  'flames',
#  'vancouver',
#  'sneezing',
#  'fibromyalgia',
#  'delious',
#  'takeout',
#  'mite',
#  'urges',
#  'ronzoni',
#  'canes',
#  'observe',
#  'chowing',
#  'bandwagon',
#  'locker',
#  '5x',
#  'demonstrated',
#  'suspended',
#  'youre',
#  'florist',
#  'unrealistic',
#  'cinnimon',
#  'fame',
#  'mellows',
#  'vanish',
#  'goop',
#  'yummmmmm',
#  'tipping',
#  'woeber',
#  'devices',
#  'epic',
#  'undergoing',
#  'bulgar',
#  'tragic',
#  'ful',
#  'employer',
#  'executed',
#  'edgy',
#  'locks',
#  'restriction',
#  'unavoidable',
#  'differentiate',
#  '40s',
#  'fend',
#  'hippo',
#  'bangers',
#  'vocal',
#  'superstore',
#  'towns',
#  'marshall',
#  'bonnet',
#  'southerner',
#  'cautionary',
#  'salame',
#  'steroid',
#  'demo',
#  'repeating',
#  'hardening',
#  'indulgences',
#  'cardboardy',
#  'mardoll',
#  'heights',
#  'weaning',
#  'brag',
#  'friggin',
#  'sleepless',
#  'philippines',
#  'eatery',
#  'belize',
#  'phenomenon',
#  'banged',
#  '425',
#  'homeopathic',
#  'wheaty',
#  'peony',
#  'accents',
#  'cosmetics',
#  'appealed',
#  'kindness',
#  'oversight',
#  'lapping',
#  'crowds',
#  'treasured',
#  'oxymoron',
#  'fizzies',
#  'virtues',
#  'esque',
#  'basting',
#  'relations',
#  'solvents',
#  'mites',
#  'ahem',
#  'invaluable',
#  '30mg',
#  'passages',
#  'mak',
#  'glands',
#  'hes',
#  'forthcoming',
#  'incomplete',
#  'gelatine',
#  'solar',
#  'nutrigrain',
#  'forbidden',
#  'paycheck',
#  'chubby',
#  'dual',
#  'chased',
#  'superfine',
#  'cheezy',
#  'jacked',
#  'alternatively',
#  'scour',
#  'garcia',
#  'intensify',
#  'ballpark',
#  'consequence',
#  'filtering',
#  'jerquee',
#  'kung',
#  'boldest',
#  'persuaded',
#  'cleveland',
#  'bulgur',
#  'insignificant',
#  'tasteing',
#  'passionfruit',
#  'silica',
#  'pardon',
#  'eighteen',
#  'anchor',
#  'accuracy',
#  'aback',
#  'penetrate',
#  'majorly',
#  'modestly',
#  'peeps',
#  'secs',
#  'backs',
#  'runts',
#  'sleeve',
#  'steals',
#  'showcase',
#  'mcvities',
#  'mechanically',
#  'teenie',
#  'survivor',
#  'volunteer',
#  'guesswork',
#  'mueslis',
#  'chickpea',
#  'workplace',
#  'crowns',
#  'snacker',
#  'bathing',
#  'airplanes',
#  'ricey',
#  'pedestrian',
#  'rugs',
#  'chipotles',
#  'tricalcium',
#  'deception',
#  'broad',
#  'greasiness',
#  'doughnuts',
#  'natasha',
#  'spat',
#  'smokeys',
#  '60mg',
#  'mimic',
#  'roaring',
#  'fido',
#  'emerils',
#  'antibacterial',
#  'ecologically',
#  'nevada',
#  'ky',
#  'midway',
#  'mahatma',
#  'determining',
#  'debacle',
#  'fertilizers',
#  'oozing',
#  'carne',
#  'urinate',
#  'mussels',
#  'columbus',
#  '165',
#  'amt',
#  'teatime',
#  '440',
#  'wandered',
#  'unheated',
#  'babyfood',
#  'shredder',
#  'drysdale',
#  'genesis',
#  'teenaged',
#  'yell',
#  'rattling',
#  'exclaimed',
#  'sifter',
#  'windsor',
#  'mouthwash',
#  'gore',
#  'descriptive',
#  'lilly',
#  'suburbs',
#  'grandchild',
#  'substitutions',
#  'reap',
#  '90mg',
#  'floppy',
#  'skyrocketed',
#  'purring',
#  'understandably',
#  'endure',
#  'practitioners',
#  'veins',
#  'istanbul',
#  'fran',
#  'bok',
#  'specializes',
#  'dismissed',
#  'booth',
#  'coal',
#  'rocked',
#  'plocky',
#  'positioned',
#  'b0014x5o1c',
#  'spree',
#  'vegi',
#  'dome',
#  'addressed',
#  'orgeat',
#  'lapped',
#  '11th',
#  'paperwork',
#  'sane',
#  'ridden',
#  'redness',
#  'pilafs',
#  'residents',
#  'nw',
#  'downstairs',
#  '64oz',
#  'agony',
#  'chocolove',
#  'maria',
#  'cadillac',
#  'janet',
#  'chocolat',
#  'inhibiting',
#  'grooming',
#  'vin',
#  'scouring',
#  'drowned',
#  'amusement',
#  'dp',
#  'subtilis',
#  'rights',
#  'mystic',
#  'crf',
#  'kickin',
#  'width',
#  'hyperactivity',
#  'azalea',
#  'catchy',
#  'adventist',
#  'beliefs',
#  'locked',
#  'reputed',
#  'rediculous',
#  'spotty',
#  'pintos',
#  'newbies',
#  'proponent',
#  'overuse',
#  'bestest',
#  'unquestionably',
#  'sponges',
#  'sapporo',
#  'stead',
#  'oaty',
#  'toddy',
#  'abilities',
#  'slush',
#  'unilever',
#  'daring',
#  'stroller',
#  'emit',
#  'cramp',
#  'chinotto',
#  'sweep',
#  'periodic',
#  'snub',
#  'detracts',
#  'facing',
#  'ken',
#  'cutlets',
#  'atmosphere',
#  'soya',
#  'weekday',
#  'consciously',
#  'prohibitively',
#  'errors',
#  'girly',
#  'norwegian',
#  'archer',
#  'forgetting',
#  '50s',
#  'rudy',
#  'babe',
#  'logical',
#  '310',
#  'inhibit',
#  'melita',
#  'strand',
#  'ooh',
#  'triggers',
#  'blurb',
#  'catechins',
#  '71',
#  'whomever',
#  'chamber',
#  'cave',
#  'balsamico',
#  'heartbroken',
#  'maya',
#  'disgust',
#  'hypoallergenic',
#  'donna',
#  'updates',
#  'bha',
#  'soledad',
#  'iii',
#  'occuring',
#  'purrfectly',
#  'generate',
#  'swift',
#  'transfats',
#  'cylinder',
#  'guinness',
#  'dosen',
#  'boards',
#  'campus',
#  'robbery',
#  'aqua',
#  'criminal',
#  'impeccable',
#  'spooning',
#  'copied',
#  'dashes',
#  'nutritionals',
#  'exceptions',
#  'goldens',
#  'valued',
#  'wi',
#  'audio',
#  'leonard',
#  'clearer',
#  'sucre',
#  'amanda',
#  'mikey',
#  'defeat',
#  '9th',
#  'satin',
#  'explicitly',
#  'references',
#  'saint',
#  'mario',
#  'screens',
#  'junkies',
#  'casino',
#  'hypnotic',
#  'peri',
#  'guatemala',
#  'ironic',
#  'b0004lzmoy',
#  'dimensions',
#  'waring',
#  'pales',
#  'fusilli',
#  'k2o',
#  'informing',
#  'safari',
#  'translucent',
#  'glutamic',
#  'blacks',
#  'healthcare',
#  'flor',
#  'elfman',
#  'stalk',
#  '91',
#  'rains',
#  'glitch',
#  'smarties',
#  'swish',
#  'preserving',
#  'doneness',
#  'understands',
#  'italiano',
#  'bore',
#  'pounding',
#  'nitrate',
#  'executive',
#  'providers',
#  '30th',
#  'assembled',
#  'blobs',
#  'havn',
#  'stinking',
#  'bevmo',
#  'abuelita',
#  'slipping',
#  'nuking',
#  'sizable',
#  'smidge',
#  'tooberry',
#  'concession',
#  'raisons',
#  'medallions',
#  'snag',
#  'greatful',
#  'greg',
#  'omegas',
#  'pineapples',
#  'regretted',
#  'parasites',
#  'toothsome',
#  'bride',
#  'rendition',
#  'propylene',
#  'gulping',
#  'gee',
#  'originating',
#  'resounding',
#  'resigned',
#  'coma',
#  'insists',
#  'gadgets',
#  'thread',
#  'gracie',
#  'restore',
#  'allegedly',
#  'bacillus',
#  'scalp',
#  'moo',
#  'accomplishment',
#  'comfortably',
#  'shatila',
#  'juiced',
#  'flipping',
#  'tastebud',
#  'pretentious',
#  'expression',
#  'gras',
#  'rocher',
#  'jokes',
#  'roadside',
#  'acquaintance',
#  'jagged',
#  'gorgonzola',
#  'interaction',
#  'responsibly',
#  'wealthy',
#  'nicknamed',
#  'respected',
#  'signal',
#  'useing',
#  'dop',
#  'compensated',
#  'preservation',
#  'blocked',
#  'gins',
#  'completing',
#  'adopt',
#  'fri',
#  'lengths',
#  '290',
#  'rashes',
#  'kiddie',
#  'examine',
#  'attractively',
#  'tenderness',
#  'relieving',
#  'approximate',
#  'vent',
#  'rage',
#  'stopper',
#  'intentionally',
#  'sourcing',
#  'livers',
#  'lessened',
#  'perceived',
#  'coz',
#  'cork',
#  'fountains',
#  'federal',
#  'artery',
#  'boxing',
#  'yorker',
#  'completly',
#  'sap',
#  'samplers',
#  'milkbones',
#  'brat',
#  'channels',
#  'gnat',
#  '1982',
#  'internationally',
#  'warrior',
#  'ortega',
#  'carpets',
#  'rattle',
#  'horlicks',
#  'pbs',
#  'manna',
#  'exhibit',
#  '40th',
#  'charts',
#  'gifting',
#  'fraud',
#  'cfl',
#  'tying',
#  'bounds',
#  'devils',
#  'misrepresentation',
#  'forbid',
#  'frutose',
#  'ou',
#  'joining',
#  'domestically',
#  'yearly',
#  'trimester',
#  'quietly',
#  'stiffness',
#  'co2',
#  'campers',
#  'awe',
#  'shore',
#  'malts',
#  'effortless',
#  'perennial',
#  'argument',
#  'florentine',
#  'depressing',
#  'mildness',
#  'purr',
#  'lynn',
#  'ninety',
#  'assures',
#  'multipack',
#  '112',
#  'regulates',
#  'gen',
#  'fate',
#  'cult',
#  'flecks',
#  'translation',
#  'heed',
#  'muck',
#  'repackaged',
#  'suisse',
#  'cous',
#  'potted',
#  'tings',
#  'sally',
#  '30am',
#  'marrow',
#  'asiago',
#  'crummy',
#  'communicate',
#  'pharmaceutical',
#  'mankind',
#  'peaberry',
#  'basset',
#  'notwithstanding',
#  'sworn',
#  'appliances',
#  'slave',
#  'unsulphured',
#  'serendipitea',
#  'activated',
#  'concious',
#  'pancreatitis',
#  'marry',
#  'upping',
#  'mucus',
#  'pen',
#  'unexciting',
#  'mar',
#  'ks',
#  'overprocessed',
#  'graze',
#  'remnants',
#  'ranked',
#  'walter',
#  'carrageenan',
#  'percentages',
#  'ties',
#  'indomie',
#  'hulless',
#  'acidophilus',
#  'captivating',
#  'anonymous',
#  'solving',
#  'meltdown',
#  'considerations',
#  '23g',
#  'germans',
#  'seared',
#  '1930s',
#  'mestemacher',
#  'relevant',
#  'incidents',
#  'gripes',
#  'toblerone',
#  'downer',
#  'alternating',
#  'unremarkable',
#  'ut',
#  'tuned',
#  'infamous',
#  'inflation',
#  'tractor',
#  'maggie',
#  'exposing',
#  'conversion',
#  'mackerel',
#  ...]

# %%
covariace_mat = np.array([[0 for x in range(2000)] for x in range(2000)])
index_col=top_features[:3000]

cov_df=pd.DataFrame(covariace_mat,index=index_col,columns=index_col)
for sentance in tqdm(X_train):
    words=sentance.split(" ")
    for i in range(len(words)):               
        for j in range(i-4,i+5):           
            if(j>=0 and j<len(words)):
                if(words[i] in index_col and words[j] in index_col):
                    cov_df.loc[words[i], words[j]] += 1
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [58:29<00:00, 33.29it/s]

# %%
cov_df
# Out:
#                enlightening  gnc  bays  survives  320  singapore  inaccurate  \
# enlightening             10    0     0         0    0          0           0
# gnc                       0    0     0         0    0          0           0
# bays                      0    0     1         0    0          0           0
# survives                  0    0     0         8    0          0           0
# 320                       0    0     0         0    6          0           0
# singapore                 0    0     0         0    0          0           0
# inaccurate                0    0     0         0    0          0           2
# courses                   0    0     0         0    0          0           0
# baggy                     0    0     0         0    0          0           0
# yucca                     0    0     0         0    0          0           0
# yelling                   0    0     0         0    0          0           0
# gingersnaps               0    0     0         0    0          0           0
# steroids                  0    0     0         0    0          0           0
# meatball                  0    0     0         0    0          0           0
# carrs                     0    0     0         0    0          0           0
# curled                    0    0     0         0    0          0           0
# conspiracy                0    0     0         0    0          0           0
# yankee                    0    0     0         0    0          0           0
# hippie                    0    0     0         0    0          0           0
# parthenon                 0    0     0         0    0          0           0
# crime                     0    0     0         0    0          0           0
# swings                    0    0     0         0    0          0           0
# putrid                    0    0     0         0    0          0           0
# kukicha                   0    0     0         0    0          0           0
# stuffy                    0    0     0         0    0          0           0
# grazing                   0    0     0         0    0          0           0
# checkup                   0    0     0         0    0          0           0
# cheeper                   0    0     0         0    0          0           0
# meter                     0    0     0         0    0          0           0
# doggone                   0    0     0         0    0          0           0
# ...                     ...  ...   ...       ...  ...        ...         ...
# swing                     0    0     0         0    0          0           0
# poland                    0    0     0         0    0          0           0
# speeds                    0    0     0         0    0          0           0
# attracts                  0    0     0         0    0          0           0
# cautiously                0    0     0         0    0          0           0
# awesomely                 0    0     0         0    0          0           0
# eventhough                0    0     0         0    0          0           0
# differing                 0    0     0         0    0          0           0
# frother                   0    0     0         0    0          0           0
# liv                       0    0     0         0    0          0           0
# stimulants                0    0     0         0    0          0           0
# braggs                    0    0     0         0    0          0           0
# bountiful                 0    0     0         0    0          0           0
# supremo                   0    0     0         0    0          0           0
# markup                    0    0     0         0    0          0           0
# centerpiece               0    0     0         0    0          0           0
# allotment                 0    0     0         0    0          0           0
# approximation             0    0     0         0    0          0           0
# striking                  0    0     0         0    0          0           0
# teachers                  0    0     0         0    0          0           0
# blanc                     0    0     0         0    0          0           0
# driveway                  0    0     0         0    0          0           0
# yogart                    0    0     0         0    0          0           0
# exp                       0    0     0         0    0          0           0
# happybellies              0    0     0         0    0          0           0
# earthiness                0    0     0         0    0          0           0
# antioxidents              0    0     0         0    0          0           0
# batteries                 0    0     0         0    0          0           0
# vons                      0    0     0         0    0          0           0
# wolfs                     0    0     0         0    0          0           0
#
#                courses  baggy  yucca  ...  blanc  driveway  yogart  exp  \
# enlightening         0      0      0  ...      0         0       0    0
# gnc                  0      0      0  ...      0         0       0    0
# bays                 0      0      0  ...      0         0       0    0
# survives             0      0      0  ...      0         0       0    0
# 320                  0      0      0  ...      0         0       0    0
# singapore            0      0      0  ...      0         0       0    0
# inaccurate           0      0      0  ...      0         0       0    0
# courses              3      0      0  ...      0         0       0    0
# baggy                0      6      0  ...      0         0       0    0
# yucca                0      0      8  ...      0         0       0    0
# yelling              0      0      0  ...      0         0       0    0
# gingersnaps          0      0      0  ...      0         0       0    0
# steroids             0      0      0  ...      0         0       0    0
# meatball             0      0      0  ...      0         0       0    0
# carrs                0      0      0  ...      0         0       0    0
# curled               0      0      0  ...      0         0       0    0
# conspiracy           0      0      0  ...      0         0       0    0
# yankee               0      0      0  ...      0         0       0    0
# hippie               0      0      0  ...      0         0       0    0
# parthenon            0      0      0  ...      0         0       0    0
# crime                0      0      0  ...      0         0       0    0
# swings               0      0      0  ...      0         0       0    0
# putrid               0      0      0  ...      0         0       0    0
# kukicha              0      0      0  ...      0         0       0    0
# stuffy               0      0      0  ...      0         0       0    0
# grazing              0      0      0  ...      0         0       0    0
# checkup              0      0      0  ...      0         0       0    0
# cheeper              0      0      0  ...      0         0       0    0
# meter                0      0      0  ...      0         0       0    0
# doggone              0      0      0  ...      0         0       0    0
# ...                ...    ...    ...  ...    ...       ...     ...  ...
# swing                0      0      0  ...      0         0       0    0
# poland               0      0      0  ...      0         0       0    0
# speeds               0      0      0  ...      0         0       0    0
# attracts             0      0      0  ...      0         0       0    0
# cautiously           0      0      0  ...      0         0       0    0
# awesomely            0      0      0  ...      0         0       0    0
# eventhough           0      0      0  ...      0         0       0    0
# differing            0      0      0  ...      0         0       0    0
# frother              0      0      0  ...      0         0       0    0
# liv                  0      0      0  ...      0         0       0    0
# stimulants           0      0      0  ...      0         0       0    0
# braggs               0      0      0  ...      0         0       0    0
# bountiful            0      0      0  ...      0         0       0    0
# supremo              0      0      0  ...      0         0       0    0
# markup               0      0      0  ...      0         0       0    0
# centerpiece          0      0      0  ...      0         0       0    0
# allotment            0      0      0  ...      0         0       0    0
# approximation        0      0      0  ...      0         0       0    0
# striking             0      0      0  ...      0         0       0    0
# teachers             0      0      0  ...      0         0       0    0
# blanc                0      0      0  ...      2         0       0    0
# driveway             0      0      0  ...      0         6       0    0
# yogart               0      0      0  ...      0         0       6    0
# exp                  0      0      0  ...      0         0       0    6
# happybellies         0      0      0  ...      0         0       0    0
# earthiness           0      0      0  ...      0         0       0    0
# antioxidents         0      0      0  ...      0         0       0    0
# batteries            0      0      0  ...      0         0       0    0
# vons                 0      0      0  ...      0         0       0    0
# wolfs                0      0      0  ...      0         0       0    0
#
#                happybellies  earthiness  antioxidents  batteries  vons  wolfs
# enlightening              0           0             0          0     0      0
# gnc                       0           0             0          0     0      0
# bays                      0           0             0          0     0      0
# survives                  0           0             0          0     0      0
# 320                       0           0             0          0     0      0
# singapore                 0           0             0          0     0      0
# inaccurate                0           0             0          0     0      0
# courses                   0           0             0          0     0      0
# baggy                     0           0             0          0     0      0
# yucca                     0           0             0          0     0      0
# yelling                   0           0             0          0     0      0
# gingersnaps               0           0             0          0     0      0
# steroids                  0           0             0          0     0      0
# meatball                  0           0             0          0     0      0
# carrs                     0           0             0          0     0      0
# curled                    0           0             0          0     0      0
# conspiracy                0           0             0          0     0      0
# yankee                    0           0             0          0     0      0
# hippie                    0           0             0          0     0      0
# parthenon                 0           0             0          0     0      0
# crime                     0           0             0          0     0      0
# swings                    0           0             0          0     0      0
# putrid                    0           0             0          0     0      0
# kukicha                   0           0             0          0     0      0
# stuffy                    0           0             0          0     0      0
# grazing                   0           0             0          0     0      0
# checkup                   0           0             0          0     0      0
# cheeper                   0           0             0          0     0      0
# meter                     0           0             0          0     0      0
# doggone                   0           0             0          0     0      0
# ...                     ...         ...           ...        ...   ...    ...
# swing                     0           0             0          0     0      0
# poland                    0           0             0          0     0      0
# speeds                    0           0             0          0     0      0
# attracts                  0           0             0          0     0      0
# cautiously                0           0             0          0     0      0
# awesomely                 0           0             0          0     0      0
# eventhough                0           0             0          0     0      0
# differing                 0           0             0          0     0      0
# frother                   0           0             0          0     0      0
# liv                       0           0             0          0     0      0
# stimulants                0           0             0          0     0      0
# braggs                    0           0             0          0     0      0
# bountiful                 0           0             0          0     0      0
# supremo                   0           0             0          0     0      0
# markup                    0           0             0          0     0      0
# centerpiece               0           0             0          0     0      0
# allotment                 0           0             0          0     0      0
# approximation             0           0             0          0     0      0
# striking                  0           0             0          0     0      0
# teachers                  0           0             0          0     0      0
# blanc                     0           0             0          0     0      0
# driveway                  0           0             0          0     0      0
# yogart                    0           0             0          0     0      0
# exp                       0           0             0          0     0      0
# happybellies              0           0             0          0     0      0
# earthiness                0          10             0          0     0      0
# antioxidents              0           0             9          0     0      0
# batteries                 0           0             0         11     0      0
# vons                      0           0             0          0     0      0
# wolfs                     0           0             0          0     0     13
#
# [2000 rows x 2000 columns]

# %%
cov_df.shape
# Out:
# (2000, 2000)

# %%
tsvd_dict = {}
for i in range(1, 200):
    tsvd = TruncatedSVD(n_components=i).fit(cov_df)
    tsvd_dict[i] = tsvd

# %%
tsvd_dict[1]
# Out:
# TruncatedSVD(algorithm='randomized', n_components=1, n_iter=5,
#        random_state=None, tol=0.0)

# %%
var_list = []
for i in range(1, 200):
    tsvd_dict[i].explained_variance_ratio_
    var_list.append(tsvd_dict[i].explained_variance_ratio_)

# %%
tsvd_dict[99].explained_variance_ratio_
# Out:
# array([0.00778991, 0.00466505, 0.00418924, 0.00254148, 0.0025004 ,
#        0.00250077, 0.00233654, 0.00221247, 0.00221309, 0.00221312,
#        0.00221262, 0.00213429, 0.00212707, 0.00202014, 0.0019414 ,
#        0.00194181, 0.001937  , 0.00193533, 0.00184859, 0.00181679,
#        0.00177312, 0.001706  , 0.00169987, 0.00168473, 0.00168105,
#        0.00168221, 0.00167847, 0.00167694, 0.00167337, 0.00166471,
#        0.00165965, 0.00165612, 0.00165026, 0.00162001, 0.00157216,
#        0.00152761, 0.00150226, 0.00146243, 0.00146492, 0.00146089,
#        0.00145585, 0.00144754, 0.00144451, 0.00144027, 0.00143942,
#        0.00143739, 0.00143347, 0.00143174, 0.00142855, 0.00142752,
#        0.00142514, 0.00141985, 0.00141961, 0.00141425, 0.00140997,
#        0.00140934, 0.00140099, 0.00139658, 0.00138883, 0.00138431,
#        0.00138439, 0.00137788, 0.00137333, 0.00136507, 0.00135657,
#        0.00134708, 0.00133324, 0.00132756, 0.00130612, 0.00129913,
#        0.00128259, 0.00127098, 0.00126521, 0.00125099, 0.00124073,
#        0.00123389, 0.00122542, 0.00122291, 0.00122098, 0.0012177 ,
#        0.00121301, 0.00121162, 0.00121121, 0.00120742, 0.00120736,
#        0.00120332, 0.00120017, 0.0011956 , 0.00119095, 0.00118733,
#        0.00118275, 0.0011803 , 0.00118075, 0.00117509, 0.00117094,
#        0.0011661 , 0.00115866, 0.00115196, 0.0011473 ])

# %%
plt.figure()
plt.plot(np.cumsum(tsvd_dict[199].explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Amazon Dataset Explained Variance')
plt.show()
